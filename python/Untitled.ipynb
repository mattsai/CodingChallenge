# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from typing import List
# small problems then integrate the other problem 
# if all positives well we need just to sum it 
#        for num in nums:
#            accum+=num #  -2 -1
# if a neg comes like 4 -3 5 and it's good, we just change our code for a local max
# but what happens if I have 1 -5 3 
# What would I need the left sum that means I need to start over from the 3  -4 I don't want that -4  
#unless is like a 4 -3 5 situation
#  if accum < num :  # -2 1
#        accum = num   #1 
# those two lines can be change into  accum = (accum,num and you would get )

class Solution:
    def maxSubArray(self, nums: List[int]) -> int:
        accum =  0
        max_so_far = float('-inf')
        local_max =  float('-inf')
        #4 -3 4 

        #[-2,1,-3,4,-1,2,1,-5,4]
        for num in nums:
            accum+=num #  -2 -1
            if accum < num :  # -2 1
                accum = num   #1 
#             local_max = max(num,accum) # -2 1
            max_so_far=max(max_so_far,accum) # -2 
        return max_so_far

# %%
"""
    def maxSubArray(self, nums: List[int]) -> int:
        accum =  0
        max_so_far = float('-inf')
        local_max =  float('-inf')
        #4 -3 4 

        #[-2,1,-3,4,-1,2,1,-5,4]
        for num in nums:
            accum+=num #  -2 -1
            accum = max(accum,num)
            # if accum < num :  # -2 1
            # #     accum = num   #1 
            # local_max = max(num,accum) # -2 1
            max_so_far=max(max_so_far,accum) # -2 
        return max_so_far
"""
# Out:
# "\n    def maxSubArray(self, nums: List[int]) -> int:\n        accum =  0\n        max_so_far = float('-inf')\n        local_max =  float('-inf')\n        #4 -3 4 \n\n        #[-2,1,-3,4,-1,2,1,-5,4]\n        for num in nums:\n            accum+=num #  -2 -1\n            accum = max(accum,num)\n            # if accum < num :  # -2 1\n            # #     accum = num   #1 \n            # local_max = max(num,accum) # -2 1\n            max_so_far=max(max_so_far,accum) # -2 \n        return max_so_far\n"
