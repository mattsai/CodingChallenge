# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#1 product of 1 -1 array
def getMaxLen(nums) :
        positive = 0
        negative = 0
        res = 0

        for num in nums:
            if num > 0:
                positive += 1
                if negative > 0:
                    negative += 1
            elif num < 0:
                temp = positive
                positive=negative
                if negative > 0: positive+=1
                    
                positive = negative + 1 if negative > 0 else 0
                negative = temp + 1
            else:
                positive = 0
                negative = 0

            res = max(res, positive)

        return res
a= [1,-1,1]
getMaxLen(a)
# Out:
# 1
